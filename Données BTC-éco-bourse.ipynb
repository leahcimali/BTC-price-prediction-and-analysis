# %% [markdown]
# # Comparaison du prix du BITCOIN avec ses données

# %%
plt.figure(figsize=(20, 5))
for i in btcdata.columns :
    if i == 'Prix BTC ':
        plt.plot(btcdata[i],label = str(i),linewidth = 3,color='black')
    elif i =="Mean Time Serie" : 
        plt.plot(btcdata[i],label = "Mean Time Serie données économiques",linewidth = 3,color='red')
    else:   
        plt.plot(btcdata[i],label = str(i), linestyle='--',)
plt.legend()
plt.title("Prix BTC en comparaison avec ses données")
plt.show()

# %%
for i in btcdata.columns[:-2]:
        plt.figure(figsize=(20, 5))
        plt.plot(btcdata['Prix BTC '],label = 'Prix BTC ',linewidth = 3,color='black') 
        plt.plot(btcdata[i],label = str(i), linestyle='--',)
        plt.legend()
        plt.title("Prix BTC en comparaison avec ses données")
        plt.show()
plt.figure(figsize=(20, 5))
plt.plot(btcdata['Prix BTC '],label = 'Prix BTC ',linewidth = 3,color='black')
plt.plot(btcdata["Mean Time Serie"],label = "Mean Time Serie données BTC",linewidth = 3,color='red')        
plt.legend()
plt.title("Prix BTC en comparaison avec ses données")
plt.show()

# %% [markdown]
# # Comparaison du prix du BITCOIN avec les données économiques

# %%
plt.figure(figsize=(20, 5))
for i in btceco.columns :
    if i == 'Prix BTC ':
        plt.plot(btceco[i],label = str(i),linewidth = 3,color='black')
    elif i =="Mean Time Serie" : 
        plt.plot(btceco[i],label = "Mean Time Serie données économiques",linewidth = 3,color='red')
    else:   
        plt.plot(btceco[i],label = str(i), linestyle='--',)
plt.legend()
plt.title("Prix BTC en comparaison avec les données économiques")
plt.show()

# %%
for i in btceco.columns[:-2]:
        plt.figure(figsize=(20, 5))
        plt.plot(btceco['Prix BTC '],label = 'Prix BTC ',linewidth = 3,color='black') 
        plt.plot(btceco[i],label = str(i), linestyle='--',)
        plt.legend()
        plt.title("Prix BTC en comparaison avec les données économiques")
        plt.show()
plt.figure(figsize=(20, 5))
plt.plot(btceco['Prix BTC '],label = 'Prix BTC ',linewidth = 3,color='black')
plt.plot(btceco["Mean Time Serie"],label = "Mean Time Serie données économiques",linewidth = 3,color='red')        
plt.legend()
plt.title("Prix BTC en comparaison avec les données économiques")
plt.show()

# %% [markdown]
# # Comparaison du prix du BITCOIN avec les Données Monétaires et Boursières

# %%
plt.figure(figsize=(20, 5))
for i in btcbourse.columns :
    if i == 'Prix BTC ':
        plt.plot(btcbourse[i],label = str(i),linewidth = 3,color='black')
    elif i =="Mean Time Serie" : 
        plt.plot(btcbourse[i],label = "Mean Time Serie données économiques et boursières",linewidth = 3,color='red')
    else:   
        plt.plot(btcbourse[i],label = str(i), linestyle='--',)
plt.legend()
plt.title("Prix BTC en comparaison avec les données Monétaires et Boursières")
plt.show()

# %%
for i in btcbourse.columns[:-2]:
        plt.figure(figsize=(20, 5))
        plt.plot(btcbourse['Prix BTC '],label = 'Prix BTC ',linewidth = 3,color='black') 
        plt.plot(btcbourse[i],label = str(i), linestyle='--',)
        plt.legend()
        plt.title("Prix BTC en comparaison avec les données économiques et boursières")
        plt.show()
plt.figure(figsize=(20, 5))
plt.plot(btcbourse['Prix BTC '],label = 'Prix BTC ',linewidth = 3,color='black')
plt.plot(btcbourse["Mean Time Serie"],label = "Mean Time Serie données économiques et boursières",linewidth = 3,color='red')        
plt.legend()
plt.title("Prix BTC en comparaison avec les données économiques et boursières")
plt.show()
